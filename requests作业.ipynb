# %%
# 代码3-6
import requests

url = 'https://www.tipdm.com'
# 生成GET请求
response_queue = requests.get(url=url)
 # 查看结果类型
type(response_queue)
# Out:
# requests.models.Response

# %%
# 查看状态码
response_queue.status_code
# Out:
# 200

# %%
# 查看编码
response_queue.encoding
# Out:
# 'UTF-8'

# %%
# 查看响应头
response_queue.headers
# Out:
# {'Server': 'nginx', 'Date': 'Wed, 11 Mar 2026 04:07:03 GMT', 'Content-Type': 'text/html;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Set-Cookie': '_site_id_cookie=3; Path=/, JSESSIONID=CBBFB36755C6716CCF72569E09DAFFDC; Path=/; HttpOnly, clientlanguage=zh_CN; Path=/', 'Content-Language': 'zh-CN', 'Content-Encoding': 'gzip'}

# %%
# 查看网页内容
response_queue.text
# Out:
# '<!DOCTYPE HTML>\n<html>\n<head>\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<title>泰迪智能科技-大数据实验室建设_大数据实训平台-大数据人工智能专业建设</title>\n<meta name="keywords" content="大数据实训平台,人工智能实训平台,商务数据分析平台,大数据实验室建设,人工智能实验室建设,商务数据分析实验室建设,大数据人工智能专业建设"/>\n<meta name="description" content="广东泰迪智能科技股份有限公司（简称：泰迪智能科技）提供高校大数据实训平台,人工智能实训平台,商务数据分析平台,专注于大数据人工智能专业建设,为高校大数据实验室建设,人工智能实验室建设,商务数据分析实验室提供一体化解决方案，实现学生从理论知识到能力塑造的开放型能力成长平台,助力成就未来大数据人才"/>\n<link rel="icon" type="image/x-icon" href="/r/cms/tipdmcom/tipdmcom/tip/favicon.ico"/>\n<script type="text/javascript" src="/r/cms/jquery.js"></script>\n<script type="text/javascript" src="/r/cms/front.js"></script>\n<script type="text/javascript" src="/r/cms/tipdmcom/tipdmcom/js/jquery.SuperSlide.js"></script>\n<link type="text/css" rel="stylesheet" href="/r/cms/tipdmcom/tipdmcom/css/tip_home.css" />\n<link type="text/css" rel="stylesheet" href="/r/cms/tipdmcom/tipdmcom/css
# ...

# %%
response_queue
# Out:
# <Response [200]>

# %%
# 代码3-7
url = 'https://www.tipdm.com'
rqg = requests.get(url)
print('状态码：', rqg.status_code)  # 查看状态码
# Out:
# 状态码： 200

# %%
rqg.encoding
# Out:
# 'UTF-8'

# %%
# 若rqg.encoding结果不是utf-8，则手动指定编码
rqg.encoding = 'utf-8'
# 查看修改后的编码
rqg.encoding
# Out:
# 'utf-8'

# %%
# 代码3-8
import chardet
url = 'https://www.tipdm.com'
rqg = requests.get(url)
print('编码：', rqg.encoding)  # 查看编码
print('detect()方法检测结果：', chardet.detect(rqg.content))
# Out:
# 编码： UTF-8
# detect()方法检测结果： {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
# 将检测到的编码赋值给rqg.encoding
rqg.encoding = chardet.detect(rqg.content)['encoding']
# 查看改变后的编码
rqg.encoding
# Out:
# 'utf-8'

# %%
# 代码3-9
url = 'https://www.tipdm.com'
#设置响应头，赋值为ua
ua = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36'
}
rqg = requests.get(url, headers=ua)
print('响应头：', rqg.headers)  # 查看响应头
# Out:
# 响应头： {'Server': 'nginx', 'Date': 'Wed, 11 Mar 2026 04:07:08 GMT', 'Content-Type': 'text/html;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Set-Cookie': '_site_id_cookie=3; Path=/, JSESSIONID=BA5BA13028E7C81776686FE0A807CA3B; Path=/; HttpOnly, clientlanguage=zh_CN; Path=/', 'Content-Language': 'zh-CN', 'Content-Encoding': 'gzip'}

# %%
# 代码3-10
url = 'https://www.tipdm.com'
#获取网页，设置求网页时设定的超时时长为0.01秒，赋值给resp变量
try:
    resp = requests.get(url=url, timeout=0.01)
    print('超时时间为0.01s: ', resp)
except requests.exceptions.Timeout:
    print('超时时间为0.01s: 请求超时')
# Out:
# 超时时间为0.01s: 请求超时
